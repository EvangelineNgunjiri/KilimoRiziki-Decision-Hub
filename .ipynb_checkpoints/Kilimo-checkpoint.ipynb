# %%
#import the necessary libraries
import csv 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
# read the dataset and view the first five rows
df2 = pd.read_csv('Temperature.csv')
df2.head()
# Out:
#   Table 8.16: Mean Annual Maximum and Minimum Temperatures by Region, 2012-2022  \
# 0                                                NaN
# 1                                             Region
# 2                               Maximum Temperatures
# 3                                          N-Western
# 4                                          N-Eastern
#
#    Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1      2013.0      2014.0      2015.0      2016.0      2017.0      2018.0
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3        35.5        35.9        36.2        36.0        35.9        35.0
# 4        30.9        33.0        32.9        33.0        33.5        31.4
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9     Unnamed: 10
# 0         NaN         NaN         NaN  Degree Celsius
# 1      2019.0      2020.0      2021.0            2022
# ...

# %%
#summary of the dataset
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 11 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   Table 8.16: Mean Annual Maximum and Minimum Temperatures by Region, 2012-2022  22 non-null     object
#  1   Unnamed: 1                                                                     19 non-null     float64
#  2   Unnamed: 2                                                                     19 non-null     float64
#  3   Unnamed: 3                                                                     19 non-null     float64
#  4   Unnamed: 4                                                                     19 non-null     float64
#  5   Unnamed: 5                                                                     19 non-null     float64
# ...

# %%
#sum of the null values
df2.isnull().sum()
# Out:
# Table 8.16: Mean Annual Maximum and Minimum Temperatures by Region, 2012-2022    1
# Unnamed: 1                                                                       4
# Unnamed: 2                                                                       4
# Unnamed: 3                                                                       4
# Unnamed: 4                                                                       4
# Unnamed: 5                                                                       4
# Unnamed: 6                                                                       4
# Unnamed: 7                                                                       4
# Unnamed: 8                                                                       4
# Unnamed: 9                                                                       4
# Unnamed: 10                                                                      3
# dtype: int64

# %%
# Drop the missing values
df2 = df2.dropna()
df2.head()
# Out:
#   Table 8.16: Mean Annual Maximum and Minimum Temperatures by Region, 2012-2022  \
# 1                                             Region
# 3                                          N-Western
# 4                                          N-Eastern
# 5                                            Western
# 6                                      C-Rift Valley
#
#    Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 1      2013.0      2014.0      2015.0      2016.0      2017.0      2018.0
# 3        35.5        35.9        36.2        36.0        35.9        35.0
# 4        30.9        33.0        32.9        33.0        33.5        31.4
# 5        26.2        26.2        26.9        26.6        26.2        25.3
# 6        24.0        24.4        24.9        24.7        25.3        24.0
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9 Unnamed: 10
# 1      2019.0      2020.0      2021.0        2022
# 3        36.0        35.4        36.1        35.9
# ...

# %%
# drop the first row
df2.drop(1, inplace=True)

# %%
#checking the datset to confirm if the first row was dropped
df2.head()
# Out:
#   Table 8.16: Mean Annual Maximum and Minimum Temperatures by Region, 2012-2022  \
# 3                                          N-Western
# 4                                          N-Eastern
# 5                                            Western
# 6                                      C-Rift Valley
# 7                                            Central
#
#    Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 3        35.5        35.9        36.2        36.0        35.9        35.0
# 4        30.9        33.0        32.9        33.0        33.5        31.4
# 5        26.2        26.2        26.9        26.6        26.2        25.3
# 6        24.0        24.4        24.9        24.7        25.3        24.0
# 7        23.9        24.0        24.6        24.0        25.0        24.1
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9 Unnamed: 10
# 3        36.0        35.4        36.1        35.9
# 4        32.5        31.3        31.0        32.1
# ...

# %%
# Arrange the columns appropriately
df2.columns = ['Region', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
df2.columns
# Out:
# Index(['Region', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '2021', '2022'],
#       dtype='object')

# %%
# Ensure data types are appropriate
df2['Region'] = df2['Region'].astype(str)

# %%
df2.head()
# Out:
#           Region  2013  2014  2015  2016  2017  2018  2019  2020  2021  2022
# 3      N-Western  35.5  35.9  36.2  36.0  35.9  35.0  36.0  35.4  36.1  35.9
# 4      N-Eastern  30.9  33.0  32.9  33.0  33.5  31.4  32.5  31.3  31.0  32.1
# 5        Western  26.2  26.2  26.9  26.6  26.2  25.3  26.6  25.8  26.3  26.5
# 6  C-Rift Valley  24.0  24.4  24.9  24.7  25.3  24.0  25.2  24.1  24.6  24.9
# 7        Central  23.9  24.0  24.6  24.0  25.0  24.1  25.2  24.4  24.9  25.0

# %%
#check columns
df2.columns
# Out:
# Index(['Region', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '2021', '2022'],
#       dtype='object')

# %%
#statistic summary
df2.describe()
# Out:
#             2013       2014       2015       2016       2017       2018  \
# count  18.000000  18.000000  18.000000  18.000000  18.000000  18.000000
# mean   22.666667  22.922222  23.227778  23.138889  23.150000  22.527778
# std     7.028848   7.210985   7.291801   7.240258   7.443374   6.977258
# min    10.300000  10.400000  10.700000  10.500000  10.200000  10.700000
# 25%    17.125000  17.225000  17.500000  17.425000  17.350000  17.200000
# 50%    23.950000  24.100000  24.650000  24.350000  24.500000  24.050000
# 75%    27.625000  27.925000  28.475000  28.175000  28.300000  27.250000
# max    35.500000  35.900000  36.200000  36.000000  35.900000  35.000000
#
#             2019       2020       2021
# count  18.000000  18.000000  18.000000
# mean   23.283333  22.961111  23.061111
# std     7.066512   6.734995   7.137155
# min    11.200000  11.700000  10.900000
# 25%    17.700000  17.425000  17.850000
# 50%    24.750000  24.300000  24.100000
# 75%    28.250000  27.525000  28.025000
# ...

# %%
#drop the country column its the mean of the maximum temperature
df2 = df2[df2['Region'] != 'Country']

# %%
df2
# Out:
#            Region  2013  2014  2015  2016  2017  2018  2019  2020  2021  2022
# 3       N-Western  35.5  35.9  36.2  36.0  35.9  35.0  36.0  35.4  36.1  35.9
# 4       N-Eastern  30.9  33.0  32.9  33.0  33.5  31.4  32.5  31.3  31.0  32.1
# 5         Western  26.2  26.2  26.9  26.6  26.2  25.3  26.6  25.8  26.3  26.5
# 6   C-Rift Valley  24.0  24.4  24.9  24.7  25.3  24.0  25.2  24.1  24.6  24.9
# 7         Central  23.9  24.0  24.6  24.0  25.0  24.1  25.2  24.4  24.9  25.0
# 8         Nairobi  25.5  25.7  26.3  25.8  26.0  24.4  25.3  24.7  24.1  24.9
# 9       S-Eastern  28.6  28.5  29.2  28.9  29.0  28.2  28.9  28.3  30.6  28.8
# 10        Coastal  30.5  30.7  30.9  31.0  31.0  30.7  31.0  30.8  31.0  30.5
# 13      N-Western  24.3  24.2  24.7  24.9  23.8  24.7  24.3  24.7  24.1  24.8
# 14      N-Eastern  21.1  21.1  20.9  21.4  22.5  20.6  21.6  21.7  21.2  21.8
# 15        Western  13.8  13.8  14.2  14.2  13.1  13.3  14.6  14.6  14.3  14.9
# ...

# %%
#Melting reshapes the DataFrame to have a single column for variable names and another column for the corresponding values, essentially converting it from a wider shape to a longer shape.
# Melt the DataFrame for a line plot
df2_melted = pd.melt(df2, id_vars=['Region'], var_name='Year', value_name='Temperature')

# Convert the 'Year' and 'Temperature' columns to numeric
df2_melted['Year'] = pd.to_numeric(df2_melted['Year'], errors='coerce')
df2_melted['Temperature'] = pd.to_numeric(df2_melted['Temperature'], errors='coerce')

# Create a line plot
plt.figure(figsize=(12, 8))
sns.lineplot(x='Year', y='Temperature', hue='Region', data=df2_melted, marker='o')
plt.title('Line Plot of Mean Annual Maximum and Minimum Temperatures by Region (2013-2022)')
plt.xlabel('Year')
plt.ylabel('Temperature (°C)')
plt.grid(True)
plt.show()

# %% [markdown]
# From the lineplot above, we can see that N-Western is the region with the highest Mean Annual Minimum and Maximum Temperatures from 2013 all through 2022 at a temperature of 30 degrees followed by Central at 28 degrees.

# %%
# Plotting using seaborn
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Temperature', data=df2_melted, hue='Region', marker='o')
plt.title('Temperature Change Over the Years by Region')
plt.xlabel('Year')
plt.ylabel('Temperature')
plt.show()

# %% [markdown]
# From tha linegraph above, N-Eastern experienced a major change in temperature from 2017.
# Naironi also experienced a change in temperature from 2017 as well

# %%
# Plotting using seaborn
plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='Temperature', data=df2_melted, hue='Region')
plt.title('Temperature Change Over the Years by Region')
plt.xlabel('Year')
plt.ylabel('Temperature')
plt.show()

# %% [markdown]
# The graph represents the temperature change over the years as well.

# %% [markdown]
# ## Modelling
# ### Model: Time Series Forecasting and Regression
# Algorithm: SARIMA (Seasonal Autoregressive Integrated Moving Average) or LSTM (Long Short-Term Memory) for prediction on the agricultural contribution towards GDP. Lasso Regression, Ridge Regression, or Gradient Boosting to estimate the contribution of agricultural practices to GDP.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tools.eval_measures import mse
from sklearn.model_selection import train_test_split

# Replace 'Region' and 'Temperature' with the actual column names
region_column = 'Region'
temperature_columns = ['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']

# Convert years to datetime
df2[temperature_columns] = df2[temperature_columns].apply(pd.to_numeric, errors='coerce')

# Set 'Region' as the index using set_index
df2.set_index(region_column, inplace=True)

# Transpose the DataFrame to have 'Year' as the index
df2_transposed = df2[temperature_columns].transpose()

# Visualize the time series data
plt.figure(figsize=(10, 6))
for region in df2_transposed.columns:
    plt.plot(df2_transposed.index, df2_transposed[region], label=region)

plt.title('Temperature Time Series')
plt.xlabel('Year')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.show()

# %%
# %matplotlib inline

df2.plot(figsize = (16,6));

# %%
# Draw a dot plot using temp and .plot() method 
df2.plot(figsize = (20,6), style = '.b');

# %%
df2.hist(figsize = (10,5));

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df_melted is your melted DataFrame
print("Column Names:", df2_melted.columns)
print("Unique Regions:", df2_melted['Region'].unique())

# Check if 'Region' is present in the melted DataFrame
if 'Region' in df2_melted.columns:
    # Plot the line plot
    plt.figure(figsize=(12, 8))
    sns.lineplot(x='Year', y='Temperature', hue='Region', data=df2_melted, marker='o')
    plt.title('Line Plot of Mean Annual Temperature')
    plt.show()
else:
    print("'Region' column not found in the melted DataFrame.")
# Out:
# Column Names: Index(['Region', 'Year', 'Temperature'], dtype='object')
# Unique Regions: ['N-Western' 'N-Eastern' 'Western' 'C-Rift Valley' 'Central' 'Nairobi'
#  'S-Eastern' 'Coastal']

# %%
def plot_rolling_statistics(timeseries, window=12):
    rolling_mean = timeseries.rolling(window=window).mean()
    rolling_std = timeseries.rolling(window=window).std()

    plt.figure(figsize=(10, 6))
    plt.plot(timeseries, label='Original')
    plt.plot(rolling_mean, label='Rolling Mean')
    plt.plot(rolling_std, label='Rolling Std')
    plt.title('Rolling Mean & Standard Deviation')
    plt.legend()
    plt.show()

# Apply the function to your time series data
plot_rolling_statistics(df2_transposed['N-Western'])

# %%
# Differencing to make the time series stationary
df2_transposed_diff = df2_transposed.diff().dropna()

# %%
plot_rolling_statistics(df2_transposed_diff['N-Western'])

# %%
# Plot the autocorrelation function
plot_acf(column_series, lags=len(column_series)-1)
plt.title('Autocorrelation Function (ACF)')
plt.show()

# %%
# Calculate the maximum allowable number of lags (50% of the sample size)
max_lags = len(column_series) // 2

# Choose the smaller of 9 and the maximum allowable number of lags
num_lags = min(9, max_lags - 1)

# Plot the partial autocorrelation function
plot_pacf(column_series, lags=num_lags)
plt.title('Partial Autocorrelation Function (PACF)')
plt.show()

# %%
# Differencing to make the time series stationary
column_series_diff = np.diff(column_series)

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(column_series, order=(1, 1, 0))
results = model.fit()

# %%
forecast_steps = 10  # Adjust the number of steps as needed
forecast = results.get_forecast(steps=forecast_steps)

# %%
plt.plot(column_series, label='Original')
plt.plot(np.arange(len(column_series), len(column_series)+forecast_steps), forecast.predicted_mean, label='Forecast', color='red')
plt.title('ARIMA Model Forecast')
plt.xlabel('Time')
plt.ylabel('YourVariable')
plt.legend()
plt.show()
