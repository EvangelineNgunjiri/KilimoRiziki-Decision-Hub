# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime
import seaborn as sns

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv("C:/Users/six/Desktop/Moringa/pHASE_5/wfp_food_prices_ken.csv")
df.head(30)
# Out:
#           date         admin1       admin2                      market  \
# 0        #date     #adm1+name   #adm2+name            #loc+market+name
# 1   15/01/2012          Coast      Mombasa                     Mombasa
# 2   15/01/2012          Coast      Mombasa                     Mombasa
# 3   15/01/2012          Coast      Mombasa                     Mombasa
# 4   15/01/2012          Coast      Mombasa                     Mombasa
# 5   15/01/2012        Eastern        Kitui                       Kitui
# 6   15/01/2012        Eastern        Kitui                       Kitui
# 7   15/01/2012        Eastern        Kitui                       Kitui
# 8   15/01/2012        Eastern     Marsabit                    Marsabit
# 9   15/01/2012        Nairobi      Nairobi                     Nairobi
# 10  15/01/2012        Nairobi      Nairobi                     Nairobi
# 11  15/01/2012        Nairobi      Nairobi                     Nairobi
# 12  15/01/2012        Nairobi      Nairobi                     Nairobi
# 13  15/01/2012        Nairobi      Nairobi                     Nairobi
# 14  15/01/2012  North Eastern      Mandera                     Mandera
# 15  15/01/2012         Nyanza       Kisumu                      Kisumu
# 16  15/01/2012         Nyanza       Kisumu                      Kisumu
# 17  15/01/2012         Nyanza       Kisumu                      Kisumu
# 18  15/01/2012         Nyanza       Kisumu                      Kisumu
# 19  15/01/2012    Rift Valley       Nakuru                      Nakuru
# 20  15/01/2012    Rift Valley       Nakuru                      Nakuru
# 21  15/01/2012    Rift Valley      Turkana            Lodwar (Turkana)
# 22  15/01/2012    Rift Valley  Uasin Gishu  Eldoret town (Uasin Gishu)
# 23  15/01/2012    Rift Valley  Uasin Gishu  Eldoret town (Uasin Gishu)
# 24  15/01/2012    Rift Valley  Uasin Gishu  Eldoret town (Uasin Gishu)
# 25  15/01/2012    Rift Valley  Uasin Gishu  Eldoret town (Uasin Gishu)
# 26  15/01/2012    Rift Valley  Uasin Gishu  Eldoret town (Uasin Gishu)
# 27  15/02/2012          Coast      Mombasa                     Mombasa
# 28  15/02/2012          Coast      Mombasa                     Mombasa
# 29  15/02/2012          Coast      Mombasa                     Mombasa
#
#     longitude         commodity        unit         priceflag  \
# 0    #geo+lon        #item+name  #item+unit  #item+price+flag
# 1   39.666667     Maize (white)       90 KG            actual
# 2   39.666667  Potatoes (Irish)       50 KG            actual
# 3   39.666667             Beans          KG            actual
# 4   39.666667       Beans (dry)       90 KG            actual
# 5   38.016667     Maize (white)          KG            actual
# 6   38.016667  Potatoes (Irish)       50 KG            actual
# 7   38.016667       Beans (dry)          KG            actual
# 8   37.983333     Maize (white)          KG            actual
# 9   36.816667             Maize          KG            actual
# 10  36.816667     Maize (white)       90 KG            actual
# 11  36.816667  Potatoes (Irish)       50 KG            actual
# 12  36.816667             Beans          KG            actual
# 13  36.816667       Beans (dry)       90 KG            actual
# 14  41.858383     Maize (white)          KG            actual
# 15      34.75     Maize (white)       90 KG            actual
# 16      34.75  Potatoes (Irish)       50 KG            actual
# 17      34.75             Beans          KG            actual
# 18      34.75       Beans (dry)       90 KG            actual
# 19    36.0744             Maize          KG            actual
# 20    36.0744             Beans          KG            actual
# 21       35.6     Maize (white)          KG            actual
# 22  35.283333             Maize          KG            actual
# 23  35.283333     Maize (white)       90 KG            actual
# 24  35.283333  Potatoes (Irish)       50 KG            actual
# 25  35.283333             Beans          KG            actual
# 26  35.283333       Beans (dry)       90 KG            actual
# 27  39.666667     Maize (white)       90 KG            actual
# 28  39.666667  Potatoes (Irish)       50 KG            actual
# 29  39.666667       Beans (dry)       90 KG            actual
#
#            pricetype   currency    price    usdprice
# 0   #item+price+type  #currency   #value  #value+usd
# 1          Wholesale        KES     3020     35.5983
# 2          Wholesale        KES     2180     25.6968
# 3          Wholesale        KES    62.49      0.7366
# 4          Wholesale        KES     5470     64.4777
# 5             Retail        KES       42      0.4951
# 6          Wholesale        KES  1888.88     22.2652
# 7             Retail        KES       72      0.8487
# 8             Retail        KES     50.9         0.6
# 9          Wholesale        KES    34.49      0.4066
# 10         Wholesale        KES     3000     35.3625
# 11         Wholesale        KES  2138.88      25.212
# 12         Wholesale        KES    58.57      0.6904
# 13         Wholesale        KES     5200     61.2951
# 14            Retail        KES       76      0.8959
# 15         Wholesale        KES     3600      42.435
# 16         Wholesale        KES  2666.66     31.4333
# 17         Wholesale        KES    74.75      0.8811
# 18         Wholesale        KES     6500     76.6188
# 19         Wholesale        KES    31.99      0.3771
# 20         Wholesale        KES    57.66      0.6797
# 21            Retail        KES    61.35      0.7232
# 22         Wholesale        KES    32.49       0.383
# 23         Wholesale        KES     2800      33.005
# 24         Wholesale        KES  1388.88     16.3714
# 25         Wholesale        KES    77.03       0.908
# 26         Wholesale        KES     5400     63.6526
# 27         Wholesale        KES     2830     34.7576
# 28         Wholesale        KES  1638.88     20.1285
# 29         Wholesale        KES     5170     63.4971

# %%
# Select specific rows based on item names
selected_items = ['Maize', 'Beans', 'Sugarcane', 'Potatoes','Bananas']
filtered_df = df[df['commodity'].isin(selected_items)]
filtered_df.head(3000)
# Out:
#              date         admin1   admin2                 market    longitude  \
# 3      15/01/2012          Coast  Mombasa                Mombasa    39.666667
# 9      15/01/2012        Nairobi  Nairobi                Nairobi    36.816667
# 12     15/01/2012        Nairobi  Nairobi                Nairobi    36.816667
# 17     15/01/2012         Nyanza   Kisumu                 Kisumu        34.75
# 19     15/01/2012    Rift Valley   Nakuru                 Nakuru      36.0744
# ...           ...            ...      ...                    ...          ...
# 13402  15/07/2023    Rift Valley  Turkana  Kalobeyei (Village 1)  34.72799937
# 13412  15/07/2023    Rift Valley  Turkana  Kalobeyei (Village 2)  34.75283168
# 13421  15/07/2023    Rift Valley  Turkana  Kalobeyei (Village 3)  34.85746868
# 13441  15/07/2023    Rift Valley  Turkana     Mogadishu (Kakuma)    34.850333
# 13450  15/08/2023  North Eastern  Garissa     Dagahaley (Daadab)    40.291621
#
#       commodity  unit  priceflag  pricetype currency  price usdprice
# 3         Beans    KG     actual  Wholesale      KES  62.49   0.7366
# 9         Maize    KG     actual  Wholesale      KES  34.49   0.4066
# 12        Beans    KG     actual  Wholesale      KES  58.57   0.6904
# 17        Beans    KG     actual  Wholesale      KES  74.75   0.8811
# 19        Maize    KG     actual  Wholesale      KES  31.99   0.3771
# ...         ...   ...        ...        ...      ...    ...      ...
# 13402     Maize    KG  aggregate     Retail      KES   82.5   0.5834
# 13412     Maize    KG  aggregate     Retail      KES     95   0.6718
# 13421     Maize    KG  aggregate     Retail      KES     80   0.5657
# 13441   Bananas  Unit  aggregate     Retail      KES     20   0.1414
# 13450   Bananas  Unit  aggregate     Retail      KES     10     0.07
#
# [1440 rows x 12 columns]

# %%
filtered_df['commodity'] = filtered_df['commodity'].replace('Maize \(white\)', 'Maize', regex=True)

# %%
view_data =filtered_df[(filtered_df['commodity'] == 'Maize')]
view_data
# Out:
#             date       admin1       admin2                      market  \
# 9     2012-01-15      Nairobi      Nairobi                     Nairobi
# 19    2012-01-15  Rift Valley       Nakuru                      Nakuru
# 22    2012-01-15  Rift Valley  Uasin Gishu  Eldoret town (Uasin Gishu)
# 34    2012-02-15      Nairobi      Nairobi                     Nairobi
# 44    2012-02-15  Rift Valley       Nakuru                      Nakuru
# ...          ...          ...          ...                         ...
# 13350 2023-07-15  Rift Valley      Turkana           HongKong (Kakuma)
# 13388 2023-07-15  Rift Valley      Turkana                    Kakuma 4
# 13402 2023-07-15  Rift Valley      Turkana       Kalobeyei (Village 1)
# 13412 2023-07-15  Rift Valley      Turkana       Kalobeyei (Village 2)
# 13421 2023-07-15  Rift Valley      Turkana       Kalobeyei (Village 3)
#
#          longitude commodity unit  priceflag  pricetype currency  price  year
# 9        36.816667     Maize   KG     actual  Wholesale      KES  34.49  2012
# 19         36.0744     Maize   KG     actual  Wholesale      KES  31.99  2012
# 22       35.283333     Maize   KG     actual  Wholesale      KES  32.49  2012
# 34       36.816667     Maize   KG     actual  Wholesale      KES  30.20  2012
# 44         36.0744     Maize   KG     actual  Wholesale      KES  27.82  2012
# ...            ...       ...  ...        ...        ...      ...    ...   ...
# 13350     34.83929     Maize   KG  aggregate     Retail      KES  75.00  2023
# 13388    34.806445     Maize   KG  aggregate     Retail      KES  85.00  2023
# 13402  34.72799937     Maize   KG  aggregate     Retail      KES  82.50  2023
# 13412  34.75283168     Maize   KG  aggregate     Retail      KES  95.00  2023
# 13421  34.85746868     Maize   KG  aggregate     Retail      KES  80.00  2023
#
# [705 rows x 12 columns]

# %%
commodity_list = filtered_df['commodity'].unique()

# Print the list of commodity items
print("List of Commodity Items:")
for item in commodity_list:
    print(item)
# Out:
# List of Commodity Items:
# Beans
# Maize
# Bananas

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1440 entries, 3 to 13450
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1440 non-null   datetime64[ns]
#  1   admin1     1440 non-null   object
#  2   admin2     1440 non-null   object
#  3   market     1440 non-null   object
#  4   longitude  1440 non-null   object
#  5   commodity  1440 non-null   object
#  6   unit       1440 non-null   object
#  7   priceflag  1440 non-null   object
#  8   pricetype  1440 non-null   object
#  9   currency   1440 non-null   object
#  10  price      1440 non-null   float64
#  11  year       1440 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(9)
# memory usage: 146.2+ KB

# %%
filtered_df = filtered_df.drop('usdprice', axis=1)

# %%
filtered_df.head(5)
# Out:
#           date       admin1   admin2   market  longitude commodity unit  \
# 3   15/01/2012        Coast  Mombasa  Mombasa  39.666667     Beans   KG
# 9   15/01/2012      Nairobi  Nairobi  Nairobi  36.816667     Maize   KG
# 12  15/01/2012      Nairobi  Nairobi  Nairobi  36.816667     Beans   KG
# 17  15/01/2012       Nyanza   Kisumu   Kisumu      34.75     Beans   KG
# 19  15/01/2012  Rift Valley   Nakuru   Nakuru    36.0744     Maize   KG
#
#    priceflag  pricetype currency  price
# 3     actual  Wholesale      KES  62.49
# 9     actual  Wholesale      KES  34.49
# 12    actual  Wholesale      KES  58.57
# 17    actual  Wholesale      KES  74.75
# 19    actual  Wholesale      KES  31.99

# %% [markdown]
# # Visualization of Maize prices over the Years 2012 -2023

# %%
# Clean the 'price' column
filtered_df['price'] = pd.to_numeric(filtered_df['price'], errors='coerce')

# Select only Maize data and only wholesale prices
maize_data_wholesale = filtered_df[(filtered_df['commodity'] == 'Maize') & (filtered_df['pricetype'] == 'Wholesale')]

# Calculate mean prices for wholesale Maize and unstack the result
mean_prices_wholesale = maize_data_wholesale.groupby(['year', 'commodity'])['price'].mean().unstack()

# Bar plot for wholesale prices
mean_prices_wholesale.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Mean Wholesale Prices of Maize (per kg) Over Years')
plt.xlabel('Year')
plt.ylabel('Mean wholesale Price')
plt.xticks(rotation=45)
plt.legend(title='Commodity')
plt.show()

# %%
# Clean the 'price' column
filtered_df['price'] = pd.to_numeric(filtered_df['price'], errors='coerce')

# Select only Maize data and only retail prices
maize_data_retail = filtered_df[(filtered_df['commodity'] == 'Maize') & (filtered_df['pricetype'] == 'Retail')]

# Calculate mean retail prices for Maize and unstack the result
mean_prices_retail = maize_data_retail.groupby(['year', 'commodity'])['price'].mean().unstack()

# Bar plot for mean retail prices of Maize
mean_prices_retail.plot(kind='bar', stacked=True, figsize=(10, 6), color='skyblue')
plt.title('Mean Retail Prices of Maize (per kg) Over Years')
plt.xlabel('Year')
plt.ylabel('Mean Retail Price')
plt.xticks(rotation=45)
plt.legend(title='Commodity')
plt.show()

# %% [markdown]
# # Visualization of Beans prices over the Years 2012 -2023

# %%
filtered_df = filtered_df.copy()

filtered_df['date'] = pd.to_datetime(filtered_df['date'], format='%d/%m/%Y')
filtered_df['year'] = filtered_df['date'].dt.year

# Select only Beans data
beans_data_wholesale = filtered_df[(filtered_df['commodity'] == 'Beans') & (filtered_df['pricetype'] == 'Wholesale')]

# Calculate mean prices for Beans and unstack the result
mean_prices_wholesale = beans_data_wholesale.groupby(['year', 'commodity'])['price'].mean().unstack()

# Bar plot for Beans
mean_prices_beans.plot(kind='bar', stacked=True, figsize=(10, 6), color='green')
plt.title('Mean wholesale Prices of Beans Over Years')
plt.xlabel('Year')
plt.ylabel('Mean wholesale Price')
plt.xticks(rotation=45)
plt.legend(title='Commodity')
plt.show()

# %%
filtered_df['price'] = pd.to_numeric(filtered_df['price'], errors='coerce')

# Select only Beans data and only retail prices
beans_data_retail = filtered_df[(filtered_df['commodity'] == 'Beans') & (filtered_df['pricetype'] == 'Retail')]

# Calculate mean retail prices for Beans and unstack the result
mean_prices_beans_retail = beans_data_retail.groupby(['year', 'commodity'])['price'].mean().unstack()

# Bar plot for mean retail prices of Beans
mean_prices_beans_retail.plot(kind='bar', stacked=True, figsize=(10, 6), color='green')
plt.title('Mean Retail Prices of Beans (per kg) Over Years')
plt.xlabel('Year')
plt.ylabel('Mean Retail Price')
plt.xticks(rotation=45)
plt.legend(title='Commodity')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 10
#       7 mean_prices_beans_retail = beans_data_retail.groupby(['year', 'commodity'])['price'].mean().unstack()
#       9 # Bar plot for mean retail prices of Beans
# ---> 10 mean_prices_beans_retail.plot(kind='bar', stacked=True, figsize=(10, 6), color='green')
#      11 plt.title('Mean Retail Prices of Beans (per kg) Over Years')
#      12 plt.xlabel('Year')
#
# File c:\Users\six\anaconda3\lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\six\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\six\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:450, in MPLPlot.generate(self)
#     448 def generate(self) -> None:
#     449     self._args_adjust()
# --> 450     self._compute_plot_data()
#     451     self._setup_subplots()
#     452     self._make_plot()
#
# File c:\Users\six\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:635, in MPLPlot._compute_plot_data(self)
#     633 # no non-numeric frames or series allowed
#     634 if is_empty:
# --> 635     raise TypeError("no numeric data to plot")
#     637 self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %% [markdown]
# # Visualization of Bananas prices over the Years 2012 -2023

# %%
# Select only Bananas data
bananas_data = filtered_df[filtered_df['commodity'] == 'Bananas']

# Calculate mean prices for Bananas and unstack the result
mean_prices_bananas = bananas_data.groupby(['year', 'commodity'])['price'].mean().unstack()

# Bar plot for Bananas
mean_prices_bananas.plot(kind='bar', stacked=True, figsize=(10, 6), color='orange')
plt.title('Mean Prices of Bananas Over Years')
plt.xlabel('Year')
plt.ylabel('Mean Price')
plt.xticks(rotation=45)
plt.legend(title='Commodity')
plt.show()

# %%
# Assuming filtered_df is your DataFrame
commodities_of_interest = ['Maize', 'Beans', 'Bananas']

# Filter data for selected commodities
selected_data = filtered_df[filtered_df['commodity'].isin(commodities_of_interest)]

# Create a scatter plot with color-coded points for different commodities
plt.figure(figsize=(12, 8))
sns.lineplot(x='date', y='price', hue='commodity', data=selected_data, palette='viridis')
plt.title('Commodity Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend(title='Commodity')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(x='admin2', data=filtered_df, order=filtered_df['admin2'].value_counts().index, palette='viridis')
plt.title('Areas with Most Sales: Count Plot')
plt.xlabel('Area Name')
plt.ylabel('Number of Sales')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
stats_crops = filtered_df.groupby(['commodity', 'admin1'])['price'].describe()
stats_crops
# Out:
#                          count       mean        std    min     25%     50%  \
# commodity admin1
# Bananas   Coast           40.0   9.993750   0.372942   8.41  10.000  10.000
#           Eastern         12.0   7.916667   2.274696   5.00   5.750   8.500
#           Nairobi         75.0   5.722133   1.469682   5.00   5.000   5.000
#           North Eastern   73.0  10.436849   2.304245   5.00   9.880  10.000
#           Rift Valley    127.0  18.744173   2.767870   5.00  19.540  20.000
# Beans     Coast           71.0  67.771831  15.080779  41.95  58.600  64.170
#           Nairobi         72.0  61.762500   8.350538  41.73  55.450  60.675
#           Nyanza          91.0  72.131099  10.008690  49.60  64.410  72.700
#           Rift Valley    174.0  66.825230  11.430392  44.96  59.455  65.640
# Maize     Coast           85.0  41.717059  11.491169  20.23  32.390  39.970
#           Eastern          8.0  54.826250  12.428717  40.00  41.875  57.500
#           Nairobi        192.0  39.814375   8.998246  22.17  32.380  37.725
#           North Eastern   56.0  56.764464   9.407628  45.00  50.000  51.020
#           Nyanza          49.0  36.127755   7.546921  25.67  30.940  34.950
#           Rift Valley    315.0  40.789746  17.002928  15.10  28.880  36.520
#
#                              75%     max
# commodity admin1
# Bananas   Coast          10.0000   11.67
#           Eastern        10.0000   10.00
#           Nairobi         5.6050   10.00
#           North Eastern  10.0000   18.75
#           Rift Valley    20.0000   20.00
# Beans     Coast          80.6400  110.39
#           Nairobi        65.9300   89.18
#           Nyanza         79.1000   90.20
#           Rift Valley    73.0225   99.42
# Maize     Coast          51.6700   60.00
#           Eastern        64.9975   70.00
#           Nairobi        49.0425   60.00
#           North Eastern  64.7100   80.00
#           Nyanza         38.6600   60.02
#           Rift Valley    46.3800   95.00

# %%
plt.figure(figsize=(20, 8))
sns.boxplot(x='admin1', y='price', hue='commodity', data=filtered_df)
plt.title('Boxplot of Price for Each Crop by Area')
plt.xlabel('Area')
plt.ylabel('Price')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Commodity')
plt.show()
